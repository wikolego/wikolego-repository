# %%
from matplotlib import pyplot as plt
import numpy as np

# Define X and Y variable data
# x = np.array(np.arange(-10, 10, 0.0625))
# y = (x*x*x + 27) / (x*x - 9)
# y = (x^3 + 27) / (x^2 - 9)

# x = np.linspace(10, 1000, 1000)
# y = (x*x + 9) / (x - 3) - x

x = np.linspace(-10, 10, 400)
y = x * np.log((np.e * x + 4) / x)

plt.plot(x, y)
plt.xlabel("X-axis")  # add X-axis label
plt.ylabel("Y-axis")  # add Y-axis label
plt.title("Good title")  # add title
plt.show()
# Out:
# /home/wikolego/miniconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in log
#   del sys.path[0]
