# %%
import matplotlib.pyplot as plt
import numpy as np


# Define X and Y variable data
# x = np.array(np.arange(-10, 10, 0.0625))
# y = (x*x*x + 27) / (x*x - 9)
# y = (x^3 + 27) / (x^2 - 9)

# x = np.linspace(10, 1000, 1000)
# y = (x*x + 9) / (x - 3) - x

x = np.linspace(-10, 10, 400)
y = x * np.log((np.e * x + 4) / x)

plt.plot(x, y)
plt.xlabel("X-axis")  # add X-axis label
plt.ylabel("Y-axis")  # add Y-axis label
plt.title("Good title")  # add title
plt.show()
# Out:
# C:\Users\48667\AppData\Local\Temp\ipykernel_18928\3670242254.py:14: RuntimeWarning: invalid value encountered in log
#   y = x * np.log((np.e * x + 4) / x)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definicja funkcji
def f(x):
    return (x**3 + 27) / (x**2 - 9)

def f2(x):
    return (x - 4) / np.sqrt(16 - x**2)

def f3(x):
    return x / np.arctan(x)

def f4(x):
    return np.e ** ((x ** 2) * (np.e ** x))

def f5(x):
    return 

beg = -10
end = 1
steps = 100
# print(f3(1))

# Zakres wartości x (pomijamy punkt x=3, bo to asymptota pionowa)
x = np.linspace(beg, end, steps)
# x = x[x != -4]  # Usuwamy wartość x = 3, bo tam jest asymptota pionowa
# x = x[x != 4]  # Usuwamy wartość x = 3, bo tam jest asymptota pionowa

# Rysowanie wykresu funkcji
plt.plot(x, f4(x), label=r"$y = \frac{x^3 + 27}{x^2 - 9}$", color='blue')

# Rysowanie asymptoty pionowej x = 3
plt.axvline(x=3, color='red', linestyle='--', label=r"Asymptota pionowa: $x = 3$")

# Rysowanie asymptoty ukośnej y = x
x_vals = np.linspace(beg, end, steps)
plt.plot(x_vals, x_vals, label=r"Asymptota ukośna: $y = x$", color='green', linestyle='--')

# Dodatkowe elementy wykresu
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
# plt.xlim(-10, 10)
# plt.ylim(-100, 100)
# plt.xlim(1000 - 10, 1000)
# plt.ylim(1000 - 10, 1000)
# plt.xlim(-4, 4)
plt.title("Wykres funkcji $y = \\frac{x^3 + 27}{x^2 - 9}$ i asymptot")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
