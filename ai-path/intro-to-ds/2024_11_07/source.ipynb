# %%
import pandas as pd
data = pd.read_csv("./data/titanic.csv")
data.head()
data.tail()
data.sample()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 data = pd.read_csv("./data/titanic.csv")
#       3 data.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data.loc[199, "Name"]
data.iloc[199, 3]

# %%
data.info()

# %%
data.describe()

# %%
data["Pclass"].unique()

# %%
data.info()
data.dropna() # drops NaN
data.dropna(subset=["Age"])

# %%
# new_data = data.dropna(subset=["Age"])
new_data = data.dropna(subset=["Age"], inplace=True)

# %%
# data.fillna(...)

# %%
data.drop([412, 414], inplace=True)
data.drop(["SibSp"], axis=1, inplace=True)

# %%
data[data["Age"] > 30]
data[(data["Age"] > 30) & (data["Sex"] == "female")]
data[data["Embarked"].isnull()]
data[data["Embarked"].notnull()]

# %%
data[data["Embarked"].isin(["Q", "S"])]

# %%
data.sort_values(data["Age"])

# %%
data["Sex", "Age"].groupby("Sex").mean()
data["Sex", "Age"].groupby("Sex").agg("mean", "median")
