# %% [markdown]
# <center><h1>Supercyfry</h1></center>

# %% [markdown]
# <center><h4>Czyli opracowanie MNIST za pomocą klasycznych metod i sieci neuronowych z użyciem różnych bibliotek</h4></center>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; gap: 40px;">
#
#   <div style="text-align: center;">
#     <img src="./images/Cyfra_4.webp">
#     <p>Wiktor Piórkowski</p>
#   </div>
#
#   <div style="text-align: center;">
#     <img src="./images/Cyfra_5.webp">
#     <p>Joanna Zubik</p>
#   </div>
#
# </div>

# %% [markdown]
# MNIST database - Modified National Institute of Standards and Technology database

# %% [markdown]
# <center><img src="./images/MNIST_dataset_example.png"></center>

# %% [markdown]
# <center><img src="./images/06_color_manage_grayscale.jpg"></center>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; gap: 40px;">
#
#   <div style="text-align: center;">
#     <img src="./images/Scikit_learn_logo_small.svg.png" size="200px">
#   </div>
#
#   <div style="text-align: center;">
#     <img src="./images/pytorch-e1576624094357.webp" size="200px">
#   </div>
#
#   <div style="text-align: center;">
#     <img src="./images/images.png" size="200px">
#   </div>
#
# </div>
