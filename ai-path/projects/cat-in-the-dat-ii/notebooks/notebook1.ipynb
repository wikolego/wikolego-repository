# %%
# print("group by method:\n", df.groupby(["ord_1", "ord_2"])["id"].count().reset_index(name="count"))
# print("\nvalue counts method:\n", df.value_counts(["ord_1", "ord_2"]).reset_index(name="count"))

# print("group by method:\n", df.groupby(["ord_4"])["id"].count().reset_index(name="count"))
# print("\nvalue counts method:\n", df.value_counts(["ord_4"]).reset_index(name="count"))

# changeToRare(df, "ord_2", 2000)

# df = df.drop(axis=1, labels=['id'])



# print(df)
# print(df['ord_2'])
# print(df.groupby(['ord_2'])['id'].count())
# print(df.groupby(["ord_2"])["ord_2"].count().reset_index(name="count"))

# print(df.groupby(["ord_1", "ord_2"])["id"].count().reset_index(name='count'))

# print(df.columns)

# transformColumn(df, "ord_2")

# print(df)
# print(df.groupby("ord_2")["ord_2"].count())
