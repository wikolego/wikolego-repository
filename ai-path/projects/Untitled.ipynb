# %%
import pandas as pd

df_base = pd.read_csv("winequality-red.csv")

# %%
df_base
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1 = df_base.sort_values(by="quality")
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1478            7.1             0.875         0.05             5.7      0.082
# 832            10.4             0.440         0.42             1.5      0.145
# 899             8.3             1.020         0.02             3.4      0.084
# 1374            6.8             0.815         0.00             1.2      0.267
# 459            11.6             0.580         0.66             2.2      0.074
# ...             ...               ...          ...             ...        ...
# 495            10.7             0.350         0.53             2.6      0.070
# 1403            7.2             0.330         0.33             1.7      0.061
# 1090           10.0             0.260         0.54             1.9      0.083
# 1449            7.2             0.380         0.31             2.0      0.056
# 1549            7.4             0.360         0.30             1.8      0.074
#
# ...

# %%
df2 = df_base.head(1000)
df2
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00            1.90      0.076
# 1              7.8              0.88         0.00            2.60      0.098
# 2              7.8              0.76         0.04            2.30      0.092
# 3             11.2              0.28         0.56            1.90      0.075
# 4              7.4              0.70         0.00            1.90      0.076
# ..             ...               ...          ...             ...        ...
# 995            7.7              0.60         0.06            2.00      0.079
# 996            5.6              0.66         0.00            2.20      0.087
# 997            5.6              0.66         0.00            2.20      0.087
# 998            8.9              0.84         0.34            1.40      0.050
# 999            6.4              0.69         0.00            1.65      0.055
#
# ...

# %%
from matplotlib import pyplot as plt

# df["volatile acidity"].plot()

x_data = df2[df2.columns[11]]
y_data = df2[df2.columns[1]]

plt.scatter(x_data, y_data)
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(18, 6))

columns = df2.columns[:]
categories = [3, 4, 5, 6, 7, 8]
print(categories)

captured_index = 2
y_data = df2[df2.columns[captured_index]]

index = 0
for r in range(2):
    for c in range(5):
        if index == captured_index:
            index += 1
        column_name = columns[index]
        x_data = df2[column_name]
        ax[r][c].set_title(f"{index} - {column_name}")
        ax[r][c].scatter(x_data, y_data)
        index += 1
        
fig.subplots_adjust(hspace=0.4, wspace=0.2)
plt.suptitle(columns[captured_index] + " compared to:")
plt.show()



# interesting relations:

# fixed acidity - density
# fixed acidity - pH
# fixed acidity - critic acid
# free sulfur dioxide - total sulfur dioxide
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
import numpy as np

categories = np.array(df2["quality"])

colormap = np.array(['r', 'r', 'r', 'r', 'r', 'r', 'g', 'g', 'g'])

x_data = df2["citric acid"]
y_data = df2["pH"]

plt.scatter(x_data, y_data, c=colormap[categories])
plt.show()
