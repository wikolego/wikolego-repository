# %%
from matplotlib import pyplot as plt
import numpy as np

# Define X and Y variable data
# x = np.array(np.arange(-10, 10, 0.0625))
# y = (x*x*x + 27) / (x*x - 9)
# y = (x^3 + 27) / (x^2 - 9)

# x = np.linspace(10, 1000, 1000)
# y = (x*x + 9) / (x - 3) - x

x = np.linspace(-10, 10, 400)
y = x * np.log((np.e * x + 4) / x)

plt.plot(x, y)
plt.xlabel("X-axis")  # add X-axis label
plt.ylabel("Y-axis")  # add Y-axis label
plt.title("Good title")  # add title
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_20332\3568458298.py:13: RuntimeWarning: invalid value encountered in log
#   y = x * np.log((np.e * x + 4) / x)

# %%
import cv2
import os
from matplotlib import pyplot as plt
import requests

url = "https://wondermural.com/cdn/shop/files/papier-peint-paysage---foret-luxuriante-4_512x512.jpg?v=1721498780"

fileName = 'img.jpg'
if not os.path.exists(fileName):
  r = requests.get(url)
  open(fileName, 'wb').write(r.content)

img = cv2.imread("img.jpg")

img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

print(img)

plt.imshow(img, cmap=plt.get_cmap('gray'))
# Out:
# [[152 132 115 ... 140 141 142]
#  [136 122 111 ... 140 141 142]
#  [140 129 118 ... 141 142 143]
#  ...
#  [ 71  77  87 ... 157 156 153]
#  [ 84  89  94 ... 151 153 152]
#  [ 98  97  92 ... 147 151 154]]

# %%
import cv2
import os
from matplotlib import pyplot as plt
# import requests

fileName = 'image.webp'
if not os.path.exists(fileName):
  open(fileName, 'wb').write()

img = cv2.imread("image.webp")

img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

print(img)
# plt.imshow(img, cmap=plt.get_cmap('gray'))

height, width = img.shape

for r in range(height):
  for c in range(width):
    if img[r, c] < 128:
      img[r, c] = 0
    else:
      img[r, c] = 255

# print(img)
plt.imshow(img, cmap=plt.get_cmap('gray'))
# plt.imshow(img)
# Out:
# [[147 135 117 ... 140 140 140]
#  [139 125 115 ... 141 141 141]
#  [140 126 116 ... 142 142 142]
#  ...
#  [ 72  75  92 ... 156 161 156]
#  [ 77  95  92 ... 157 152 154]
#  [ 98  97  88 ... 147 153 152]]

# %%
import cv2
import os
from matplotlib import pyplot as plt

fileName = 'image.webp'
if not os.path.exists(fileName):
  open(fileName, 'wb').write()

img = cv2.imread("image.webp")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

height, width = img.shape

for r in range(height):
  for c in range(width):
    if img[r, c] < 128:
      img[r, c] = 0
    else:
      img[r, c] = 255

plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
histogram = cv2.calcHist([img], [0], None, [256], [0, 256])

plt.plot(histogram)
plt.show()
