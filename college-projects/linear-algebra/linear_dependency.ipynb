# %% [markdown]
# # Zadanie

# %% [markdown]
# ## Treść
#
# Dane mamy 4 wektory: v1 = [0, 1, 2, 3], v2 = [4, 5, 6, 7], v3 = [8, 9, 0, 1], v4 = [2, 3, 4, 5]. Zbadaj ich liniową zależność oraz przedstaw wektory zależne za pomocą wektorów niezależnych.
